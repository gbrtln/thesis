# %%
# Import built-in and third-party libraries
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import scipy
from scipy import stats
import seaborn as sns
import sys
import warnings

# %%
# Import user-defined modules
def find_dir(dir, root=os.path.abspath('/')):
    """
    Returns path of the input directory, moving backwards along 
    the cwd path. Searches until the root directory is reached.
    
    Returns None if the file system root is reached.
    """
    cd=os.getcwd() 
    while True:
        listdir=os.listdir(cd)
        if dir in listdir:
            return cd
        elif (os.path.basename(cd)==root) or (cd==os.path.abspath('/')):
            return None
        cd=os.path.dirname(cd)

# Add utils path to sys.path
utils_path=find_dir('utils')
if utils_path not in sys.path:
    sys.path.append(utils_path)

# Load user-defined utilities
import plotting as uplot
import utils as u

# %%
# Warnings
# warnings.simplefilter('ignore')
warnings.simplefilter('default')

# Set Pandas display options
pd.set_option('display.max_columns', None)
pd.set_option ('display.max_rows', 40)
pd.set_option('display.float_format', '{:f}'.format)

# Set aspects of the visual theme for all matplotlib and seaborn plots
sns.set_theme()

# %%
# Data ingestion
# Load radiomics dataset
dataset_filename='radiogenomics.csv'
dataset_path='./' + dataset_filename # Path aprire dataset_filename nel direttorio corrente

df = pd.read_csv(  
      filepath_or_buffer=dataset_path
    , sep=','
    , on_bad_lines='warn'
    , index_col=False
    , header=0
)

# %%
dataset_path
# Out:
# './radiogenomics.csv'

# %%
df.shape
# Out:
# (144, 111)

# %%
df.head()
# Out:
#         id  original_shape_Elongation  original_shape_Flatness  \
# 0  R01-001                   0.694965                 0.481237
# 1  R01-002                   0.732610                 0.656833
# 2  R01-003                   0.720221                 0.657195
# 3  R01-004                   0.624517                 0.387075
# 4  R01-005                   0.785596                 0.671483
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                        8.963171                       18.625263
# 1                       12.548555                       19.104627
# 2                       11.036269                       16.792985
# 3                        8.513651                       21.994859
# 4                       18.349358                       27.326629
#
#    original_shape_Maximum2DDiameterColumn  \
# 0                               20.000000
# 1                               19.849433
# 2                               15.264338
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Columns: 111 entries, id to Recurrence
# dtypes: float64(106), int64(3), object(2)
# memory usage: 125.0+ KB

# %%
df['Histology'].value_counts()
# Out:
# Histology
# Adenocarcinoma                         112
# Squamous cell carcinoma                 29
# NSCLC NOS (not otherwise specified)      3
# Name: count, dtype: int64

# %%
columns = ['id', 'Histology', 'Recurrence']
df.drop(columns=columns, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Columns: 108 entries, original_shape_Elongation to Hist_binary
# dtypes: float64(106), int64(2)
# memory usage: 121.6 KB

# %%
df.select_dtypes(include=['int64']).columns.tolist()
# Out:
# ['original_shape_VoxelVolume', 'Hist_binary']

# %%
# Save features in dataframe X, and target in series y
target='Hist_binary'

X=df.drop(columns=target).copy()
y=df[target].copy()

cond=df[target]==0

# Split X
X_0=X.loc[cond].copy()
X_1=X.loc[~cond].copy()

# Split y
y_0=y.loc[cond].copy()
y_1=y.loc[~cond].copy()

# %%
# The target variable
y.unique()
# Out:
# array([0, 1])

# %%
y.value_counts()
# Out:
# Hist_binary
# 0    112
# 1     32
# Name: count, dtype: int64

# %%
y.value_counts(normalize=True)
# Out:
# Hist_binary
# 0   0.777778
# 1   0.222222
# Name: proportion, dtype: float64

# %%
# Plot a countplot of the target variable
plt.figure(figsize=(8, 6), dpi=100)

sns.countplot(data=df, y='Hist_binary')

plt.title('Target variable countplot', fontweight='bold', fontsize=16)

plt.xlabel('Absolute frequency')
plt.ylabel('')

plt.tight_layout()

plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# The features
# Missing values
X.isnull().any().any()
# Out:
# False

# %%
# Univariate analysis
X.describe()
# Out:
#        original_shape_Elongation  original_shape_Flatness  \
# count                 144.000000               144.000000
# mean                    0.783000                 0.609082
# std                     0.134629                 0.134307
# min                     0.356903                 0.243226
# 25%                     0.706108                 0.525372
# 50%                     0.806486                 0.616489
# 75%                     0.890484                 0.699870
# max                     0.993023                 0.876888
#
#        original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# count                      144.000000                      144.000000
# mean                        21.821366                       36.744517
# std                         12.216767                       19.491069
# min                          7.602185                       11.023599
# 25%                         13.803164                       22.611010
# ...

# %%
X_norm=(X-X.min()) / (X.max()-X.min())

X_norm.describe()
# Out:
#        original_shape_Elongation  original_shape_Flatness  \
# count                 144.000000               144.000000
# mean                    0.669838                 0.577368
# std                     0.211640                 0.211953
# min                     0.000000                 0.000000
# 25%                     0.548960                 0.445263
# 50%                     0.706759                 0.589058
# 75%                     0.838806                 0.720643
# max                     1.000000                 1.000000
#
#        original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# count                      144.000000                      144.000000
# mean                         0.210988                        0.276111
# std                          0.181276                        0.209235
# min                          0.000000                        0.000000
# 25%                          0.092012                        0.124390
# ...

# %%
# Skewness
X.apply(lambda x: stats.skew(x, bias=False), axis=0).to_frame(name='skew').T
# Out:
#       original_shape_Elongation  original_shape_Flatness  \
# skew                  -0.762535                -0.249734
#
#       original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# skew                        1.676258                        1.256550
#
#       original_shape_Maximum2DDiameterColumn  \
# skew                                1.405105
#
#       original_shape_Maximum2DDiameterRow  \
# skew                             1.260244
#
#       original_shape_Maximum2DDiameterSlice  original_shape_Maximum3DDiameter  \
# skew                               1.002778                          1.122106
#
#       original_shape_MeshVolume  original_shape_MinorAxisLength  \
# skew                   4.296786                        1.438061
#
#       original_shape_Sphericity  original_shape_SurfaceArea  \
# skew                  -0.168686                    3.584323
#
#       original_shape_SurfaceVolumeRatio  original_shape_VoxelVolume  \
# ...

# %%
X.apply(lambda x: stats.kurtosis(x, bias=False), axis=0).to_frame(name='ekurt').T
# Out:
#        original_shape_Elongation  original_shape_Flatness  \
# ekurt                   0.190175                -0.265774
#
#        original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# ekurt                        3.399469                        1.485157
#
#        original_shape_Maximum2DDiameterColumn  \
# ekurt                                2.135443
#
#        original_shape_Maximum2DDiameterRow  \
# ekurt                             1.487717
#
#        original_shape_Maximum2DDiameterSlice  \
# ekurt                               0.667689
#
#        original_shape_Maximum3DDiameter  original_shape_MeshVolume  \
# ekurt                          1.010253                  21.378357
#
#        original_shape_MinorAxisLength  original_shape_Sphericity  \
# ekurt                        2.416439                  -0.532009
#
#        original_shape_SurfaceArea  original_shape_SurfaceVolumeRatio  \
# ekurt                   17.605758                          -0.301801
#
# ...

# %%
stats_df=pd.concat(
    [
        X.describe()
      , X.apply(lambda x: stats.skew(x, bias=False), axis=0).to_frame(name='skew').T
      , X.apply(lambda x: stats.kurtosis(x, bias=False), axis=0).to_frame(name='ekurt').T
    ]
  , axis=0
)

stats_df
# Out:
#        original_shape_Elongation  original_shape_Flatness  \
# count                 144.000000               144.000000
# mean                    0.783000                 0.609082
# std                     0.134629                 0.134307
# min                     0.356903                 0.243226
# 25%                     0.706108                 0.525372
# 50%                     0.806486                 0.616489
# 75%                     0.890484                 0.699870
# max                     0.993023                 0.876888
# skew                   -0.762535                -0.249734
# ekurt                   0.190175                -0.265774
#
#        original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# count                      144.000000                      144.000000
# mean                        21.821366                       36.744517
# std                         12.216767                       19.491069
# ...

# %%
# Plotting marginal distributions
# Univariate boxplot
data=df
feature='original_shape_Elongation'

uplot.boxplot(data=data, feature=feature)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Histogram
data=df
feature='original_shape_Elongation'

uplot.histogram(data=data, feature=feature, bins=10, kde=True)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Bivariate analysis
# Plot a bivariate boxplot
data=df
feature='original_shape_Elongation'
target='Hist_binary'

uplot.boxplot(data=data, feature=feature, target=target)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Plot a bivariate histogram
data=df
feature='original_shape_Elongation'
target='Hist_binary'

uplot.histogram(data=data, feature=feature, target=target, bins=10, kde=True)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
data=X
x='original_shape_Elongation'
y='original_shape_Flatness'

sns.scatterplot(data=data, x=x, y=y)

plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.pairplot(X.iloc[:, :4])

plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Hypotesis testing
# Normality tests
# Perform statistical tests to check if marginal distributions are normal
column='original_shape_Elongation'
data=X[column]

# Anderson test
anderson=stats.anderson(data, dist='norm')
print('Anderson-Darling:   {}'.format(anderson.statistic<anderson.critical_values[2]))

# Kolmogorov-Smirnov test
kstest=stats.kstest(data, stats.norm.cdf)
print('Kolmogorov-Smirnov: {}'.format(kstest.pvalue>.05))

# Shapiro-Wilk test
shapiro=stats.shapiro(data)
print('Shapiro-Wilk:       {}'.format(shapiro.pvalue>.05))
# Out:
# Anderson-Darling:   False
# Kolmogorov-Smirnov: False
# Shapiro-Wilk:       False

# %%
u.normality_tests(X)
# Out:
#                     original_shape_Elongation  original_shape_Flatness  \
# anderson-darling                        False                     True
# kolmogorov-smirnov                      False                    False
# shapiro-wilk                            False                     True
#
#                     original_shape_LeastAxisLength  \
# anderson-darling                             False
# kolmogorov-smirnov                           False
# shapiro-wilk                                 False
#
#                     original_shape_MajorAxisLength  \
# anderson-darling                             False
# kolmogorov-smirnov                           False
# shapiro-wilk                                 False
#
#                     original_shape_Maximum2DDiameterColumn  \
# anderson-darling                                     False
# kolmogorov-smirnov                                   False
# shapiro-wilk                                         False
#
# ...

# %%
# T-tests
column='original_shape_Elongation'

ttest=stats.ttest_ind(X_0[column].values, X_1[column].values, equal_var=False)
print('Independent T-test: {}'.format(ttest.pvalue>.05))
# Out:
# Independent T-test: True

# %%
# Correlation analysis
X.corr()
# Out:
#                                         original_shape_Elongation  \
# original_shape_Elongation                                1.000000
# original_shape_Flatness                                  0.703530
# original_shape_LeastAxisLength                           0.130560
# original_shape_MajorAxisLength                          -0.221554
# original_shape_Maximum2DDiameterColumn                   0.012621
# ...                                                           ...
# original_ngtdm_Busyness                                 -0.077835
# original_ngtdm_Coarseness                                0.097285
# original_ngtdm_Complexity                               -0.044164
# original_ngtdm_Contrast                                 -0.044765
# original_ngtdm_Strength                                  0.097629
#
#                                         original_shape_Flatness  \
# original_shape_Elongation                              0.703530
# ...

# %%
high_corr_thrsh=0.95

melt_corr_df = u.melt_corr(X)
melt_corr_df.loc[np.abs(melt_corr_df['corr_coeff'])>high_corr_thrsh]
# Out:
#                                                feat_1  \
# 316                    original_shape_MajorAxisLength
# 420            original_shape_Maximum2DDiameterColumn
# 824                         original_shape_MeshVolume
# 871                         original_shape_MeshVolume
# 1169                       original_shape_SurfaceArea
# ...                                               ...
# 5481  original_glszm_GrayLevelNonUniformityNormalized
# 5521         original_glszm_HighGrayLevelZoneEmphasis
# 5545                 original_glszm_LargeAreaEmphasis
# 5667                        original_ngtdm_Coarseness
# 5668                        original_ngtdm_Complexity
#
#                                        feat_2  corr_coeff
# 316       original_shape_Maximum2DDiameterRow    0.961812
# 420          original_shape_Maximum3DDiameter    0.956367
# 824                original_shape_VoxelVolume    1.000000
# 871      original_gldm_GrayLevelNonUniformity    0.982275
# ...

# %%
melt_corr_df.loc[np.abs(melt_corr_df['corr_coeff'])==1.]
# Out:
#                                feat_1                           feat_2  \
# 1588       original_firstorder_Energy  original_firstorder_TotalEnergy
# 3187           original_glcm_Contrast  original_glcm_DifferenceAverage
# 3193           original_glcm_Contrast                original_glcm_Idn
# 3196           original_glcm_Contrast    original_glcm_InverseVariance
# 3330  original_glcm_DifferenceAverage                original_glcm_Idn
# 3333  original_glcm_DifferenceAverage    original_glcm_InverseVariance
# 3526                 original_glcm_Id                original_glcm_Idm
#
#       corr_coeff
# 1588    1.000000
# 3187    1.000000
# 3193   -1.000000
# 3196    1.000000
# 3330   -1.000000
# 3333    1.000000
# 3526    1.000000

# %%
# Plot data correlation heatmap
uplot.corr_heatmap(
    data=X
  , figsize=(X.shape[1], X.shape[1])
  , mask=True
  , annot=True
  , cbar=True
)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
df.drop('id', axis=1, inplace=True)
df.drop('Histolgy', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 df.drop('id', axis=1, inplace=True)
#       2 df.drop('Histolgy', axis=1, inplace=True)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
# ...

# %%
target='Hist_binary'

target_corr_df=df.corr()[[target]].iloc[:-1].sort_values(by=target, ascending=False)
target_corr_df
# Out:
#                                                     Hist_binary
# original_gldm_SmallDependenceHighGrayLevelEmphasis     0.306653
# original_gldm_SmallDependenceEmphasis                  0.302281
# original_gldm_LowGrayLevelEmphasis                     0.297383
# original_glszm_HighGrayLevelZoneEmphasis               0.295807
# original_glcm_ClusterShade                             0.293627
# ...                                                         ...
# original_glszm_LowGrayLevelZoneEmphasis               -0.295807
# original_gldm_HighGrayLevelEmphasis                   -0.297383
# original_glcm_SumAverage                              -0.299660
# original_glcm_JointAverage                            -0.299660
# original_glcm_Autocorrelation                         -0.300311
#
# [107 rows x 1 columns]

# %%
target_corr_df.describe()
# Out:
#        Hist_binary
# count   107.000000
# mean      0.046861
# std       0.174903
# min      -0.300311
# 25%      -0.091734
# 50%       0.077946
# 75%       0.182350
# max       0.306653

# %%
sns.histplot(target_corr_df[target])

plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
low_corr_thrsh=0.01

target_corr_df.loc[np.abs(target_corr_df['Hist_binary'])<low_corr_thrsh]
# Out:
#                                        Hist_binary
# original_gldm_DependenceNonUniformity     0.007255
# original_shape_SurfaceVolumeRatio        -0.005967
# original_shape_Elongation                -0.006601
# original_glcm_Correlation                -0.007503
# original_glcm_MCC                        -0.007740

# %%
# Plot correlation heatmap of features with label
target='Hist_binary'
uplot.target_corr_heatmap(
    data=df
  , target=target
  , figsize=(10, X.shape[1]/2)
  , annot=True
  , cbar=True
)
